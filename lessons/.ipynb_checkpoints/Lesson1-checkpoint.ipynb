# %% [markdown]
# ### Import libraries

# %%
import mediapipe as mp
import cv2
import numpy as np
import os

# %% [markdown]
# ### Definig Drawing and hand utils

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# %% [markdown]
# ![Image description](../hands.png)

# %% [markdown]
# ### Basic detection with walk through

# %%
cap = cv2.VideoCapture(0)

#
with mp_hands.Hands(min_detection_confidence=0.8, min_tracking_confidence=0.6) as hands: 
    while cap.isOpened():
        ret, frame = cap.read()
        
        # BGR 2 RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Flip on horizontal
        image = cv2.flip(image, 1)
        
        # Set flag
        image.flags.writeable = False
        
        # Detections
        results = hands.process(image)
        
        # Set flag to true
        image.flags.writeable = True
        
        # RGB 2 BGR
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        
        # Rendering results
        if results.multi_hand_landmarks:
            for num, hand in enumerate(results.multi_hand_landmarks):
                mp_drawing.draw_landmarks(image, hand, mp_hands.HAND_CONNECTIONS, 
                                        mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                                        mp_drawing.DrawingSpec(color=(250, 44, 250), thickness=2, circle_radius=2),
                                         )
            
        
        cv2.imshow('Hand Tracking', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Hawis\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %% [markdown]
# ### Getting which hand was detected

# %%
results.multi_handedness
# Out:
# [classification {
#    index: 1
#    score: 0.986913145
#    label: "Right"
#  }]

# %%
results.multi_handedness[0].classification[0].label
# Out:
# 'Right'

# %% [markdown]
# ## How to get the index of each part of the hands
#
# #### From the image above you can use the code snippest below to get the various index of corresponding part of the hand

# %%
# Examples below
# Getting the index of the wrist
mp_hands.HandLandmark.WRIST
# Out:
# <HandLandmark.WRIST: 0>

# %%
# Getting the index of the middle finger tip
mp_hands.HandLandmark.MIDDLE_FINGER_TIP
# Out:
# <HandLandmark.MIDDLE_FINGER_TIP: 12>

# %% [markdown]
# # Getting HandLandmarks

# %%
results.multi_hand_landmarks
# Out:
# [landmark {
#    x: 0.801817417
#    y: 0.572865844
#    z: 3.02092474e-007
#  }
#  landmark {
#    x: 0.844508
#    y: 0.511364222
#    z: 0.0046037063
#  }
#  landmark {
#    x: 0.869561672
#    y: 0.44459641
#    z: -0.00358159235
#  }
#  landmark {
#    x: 0.887145638
#    y: 0.37807864
#    z: -0.0121540222
#  }
#  landmark {
#    x: 0.910204351
#    y: 0.332631439
#    z: -0.0232583471
#  }
#  landmark {
#    x: 0.814431608
#    y: 0.35430789
#    z: -0.0303676501
#  }
#  landmark {
#    x: 0.798707545
#    y: 0.237421378
#    z: -0.0433261469
#  }
#  landmark {
#    x: 0.783084571
#    y: 0.178314924
#    z: -0.0463357083
#  }
#  landmark {
#    x: 0.770487785
#    y: 0.135812566
#    z: -0.047215566
#  }
#  landmark {
#    x: 0.778082728
#    y: 0.365771115
#    z: -0.0408854447
#  }
#  landmark {
#    x: 0.737189293
#    y: 0.240267843
#    z: -0.0535921119
#  }
#  landmark {
#    x: 0.70765543
#    y: 0.182845831
#    z: -0.0553221256
#  }
#  landmark {
#    x: 0.688784599
# ...

# %% [markdown]
# ### How to get coordinates of the parts of the hands

# %%
# Getting hand landmarks
results.multi_hand_landmarks[0].landmark[mp_hands.HandLandmark.WRIST]
# Out:
# x: 0.801817417
# y: 0.572865844
# z: 3.02092474e-007

# %%
# Getting hand landmarks
results.multi_hand_landmarks[0].landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP]
# Out:
# x: 0.688784599
# y: 0.146514952
# z: -0.0557144769

# %% [markdown]
# ### Simple function to get the coordinates of the parts of the hands specified by user

# %%
def get_label(index, hand, results):
    output = None
    for idx, classification in enumerate(results.multi_handedness):
        # if classification.classification[0].index == index:
            
        # Extract Coordinates
        coords = tuple(np.multiply(
            # Change it from wrist if you want the coordinates of a different part of the hand
            np.array((hand.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].x, hand.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].y)),
        [640,480]).astype(int))
        
        output = coords

    if output:
        return coords
    else:
        return None

# %% [markdown]
# ### Testing Functions

# %%
cap = cv2.VideoCapture(0)

with mp_hands.Hands(min_detection_confidence=0.8, min_tracking_confidence=0.5) as hands: 
    while cap.isOpened():
        ret, frame = cap.read()
        
        # BGR 2 RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Flip on horizontal
        image = cv2.flip(image, 1)
        
        # Set flag
        image.flags.writeable = False
        
        # Detections
        results = hands.process(image)
        
        # Set flag to true
        image.flags.writeable = True
        
        # RGB 2 BGR
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Rendering results
        if results.multi_hand_landmarks:
            for num, hand in enumerate(results.multi_hand_landmarks):
                mp_drawing.draw_landmarks(image, hand, mp_hands.HAND_CONNECTIONS, 
                                        mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                                        mp_drawing.DrawingSpec(color=(250, 44, 250), thickness=2, circle_radius=2),
                                         )
                
                # Render left or right detection
                coords = get_label(num, hand, results)
                if coords:
                    coords = get_label(num, hand, results)
                    cv2.circle(image, coords, 5, (255, 50, 40), 3)
        # Save our image    
        #cv2.imwrite(os.path.join('Output Images', '{}.jpg'.format(uuid.uuid1())), image)
        cv2.imshow('Hand Tracking', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import numpy as np

mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

def get_label(index, hand, results):
    output = None
    for idx, classification in enumerate(results.multi_handedness):
        coords = tuple(np.multiply(
            np.array((hand.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].x, hand.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].y)),
        [640,480]).astype(int))
        
        output = coords
    if output:
        return coords
    else:
        return None

# Initialize an empty list to store finger positions
finger_path = []
max_path_length = 50  # Adjust this value to change the length of the traced path

cap = cv2.VideoCapture(0)
with mp_hands.Hands(min_detection_confidence=0.8, min_tracking_confidence=0.5) as hands: 
    while cap.isOpened():
        ret, frame = cap.read()
        
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image = cv2.flip(image, 1)
        image.flags.writeable = False
        results = hands.process(image)
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        if results.multi_hand_landmarks:
            for num, hand in enumerate(results.multi_hand_landmarks):
                mp_drawing.draw_landmarks(image, hand, mp_hands.HAND_CONNECTIONS, 
                                        mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                                        mp_drawing.DrawingSpec(color=(250, 44, 250), thickness=2, circle_radius=2),
                                         )
                
                coords = get_label(num, hand, results)
                if coords:
                    cv2.circle(image, coords, 5, (255, 50, 40), 3)
                    
                    # Add the current position to the finger path
                    finger_path.append(coords)
                    
                    # Limit the path length
                    if len(finger_path) > max_path_length:
                        finger_path.pop(0)
                    
                    # Draw the path
                    for i in range(1, len(finger_path)):
                        cv2.line(image, finger_path[i-1], finger_path[i], (0, 255, 0), 2)

        cv2.imshow('Hand Tracking', image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
