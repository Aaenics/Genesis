# %%
import cv2

# %% [markdown]
# ### Loading Images

# %%
image = cv2.imread("../dataset/sports-car-clouds-digital-art-4k-wallpaper-uhdpaper.com-633@0@j.jpg")
cv2.imshow("Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Resizing an images

# %%
new_width = 300
new_height = 200
resized_image = cv2.resize(image, (new_width, new_height))

cv2.imshow("Image", resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
scale_factor_x = 0.25  # Resizing to 50% of the original width
scale_factor_y = 0.25  # Resizing to 50% of the original height
resized_image = cv2.resize(image, (0, 0), fx=scale_factor_x, fy=scale_factor_y)

cv2.imshow("Image", resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Recoloring Images

# %%
# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Grayscale Image', gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Drawing Images
#
# #### Rectangle

# %%
# Draw a rectangle on the image
cv2.rectangle(resized_image, (50, 50), (200, 200), (0, 255, 0), 3)
cv2.imshow('Rectangle', resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### Circle

# %%
center = (250, 250)  # (x, y) coordinates of the center
radius = 50  # Radius of the circle
color = (0, 255, 0)  # Color in BGR format (green)
thickness = 2  # Thickness of the circle border (-1 to fill the circle)

# Draw the circle on the image
cv2.circle(resized_image, center, radius, color, thickness)

# Display the image
cv2.imshow('Circle', resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Loading Video
#
# #### Computer's webcam

# %%
# loading with computers webcam
cap = cv2.VideoCapture(0)


while True:
    
    ret, frame = cap.read()
    
    if not ret or frame is None:
        print("Error: Failed to capture image")
        break
    
    cv2.imshow('frane', frame)
    
    if  cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### External webcam

# %%
# loading with computers webcam
cap = cv2.VideoCapture(1)


while True:
    
    ret, frame = cap.read()
    
    if not ret or frame is None:
        print("Error: Failed to capture image")
        break
    
    cv2.imshow('frane', frame)
    
    if  cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### Connecting wirelessly

# %%
cap = cv2.VideoCapture("http://192.168.180.193:8080/video")


while True:
    
    ret, frame = cap.read()
    
    if not ret or frame is None:
        print("Error: Failed to capture image")
        break
    
    cv2.imshow('framee', frame)
    
    if  cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
